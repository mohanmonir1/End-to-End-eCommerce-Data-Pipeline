# %%
# %sql
-- Create External location
CREATE EXTERNAL LOCATION fastenal_bronze_ext
URL 'abfss://bronze@fastenaldevsa.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `fastenal_credential`)

# %%
# %sql
CREATE CATALOG bronze
MANAGED LOCATION 'abfss://bronze@fastenaldevsa.dfs.core.windows.net/data'

# %%
# %sql
-- Create External location
CREATE EXTERNAL LOCATION fastenal_silver_ext
URL 'abfss://silver@fastenaldevsa.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `fastenal_credential`)

# %%
# %sql
CREATE CATALOG silver
MANAGED LOCATION 'abfss://silver@fastenaldevsa.dfs.core.windows.net/data'

# %%
# %sql
-- Create External location
CREATE EXTERNAL LOCATION fastenal_gold_ext
URL 'abfss://gold@fastenaldevsa.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `fastenal_credential`)

# %%
# %sql
CREATE CATALOG gold
MANAGED LOCATION 'abfss://gold@fastenaldevsa.dfs.core.windows.net/data'

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze.curated")
spark.sql("CREATE SCHEMA IF NOT EXISTS bronze.control")
